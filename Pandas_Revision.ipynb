# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=['Name', 'City', 'Grade'],
                  data=[['Saeed', 'Cairo', 88],
                        ['Karim', 'Alex', 97],
                        ['Ahmed', 'Giza', 93]])

# %%
df
# Out:
#     Name   City  Grade
# 0  Saeed  Cairo     88
# 1  Karim   Alex     97
# 2  Ahmed   Giza     93

# %%
data = {'Name': ['Saeed', 'Karim', 'Ahmed'],
        'City': ['Cairo', 'Alex', 'Giza'],
        'Grade': [88, 97, 93]}

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name   City  Grade
# 0  Saeed  Cairo     88
# 1  Karim   Alex     97
# 2  Ahmed   Giza     93

# %%
# df_tmp = pd.read_csv('data.csv')
# df_tmp

# %%
df.to_csv('data.csv', index=False)

# %%
df = pd.read_csv('5000 Sales Records.csv')
df
# Out:
#                                  Region               Country   Item Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
df.shape
# Out:
# (5000, 14)

# %%
df.size
# Out:
# 70000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5000, step=1)

# %%
list(df.columns)
# Out:
# ['Region',
#  'Country',
#  'Item Type',
#  'Sales Channel',
#  'Order Priority',
#  'Order Date',
#  'Order ID',
#  'Ship Date',
#  'Units Sold',
#  'Unit Price',
#  'Unit Cost',
#  'Total Revenue',
#  'Total Cost',
#  'Total Profit']

# %%
df.dtypes
# Out:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
df.head()
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales Channel Order Priority  Order Date   Order ID  Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544  1/11/2014         552
# 1       Offline              C    7/5/2010  301644504  7/26/2010        2167
# 2       Offline              C   9/12/2011  478051030  9/29/2011        4778
# 3       Offline              L   5/13/2010  892599952  6/15/2010        9016
# 4       Offline              C   7/20/2015  571902596  7/27/2015        7542
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df.tail()
# Out:
#                             Region      Country   Item Type Sales Channel  \
# 4995         Australia and Oceania  New Zealand   Household       Offline
# 4996  Middle East and North Africa   Azerbaijan     Clothes       Offline
# 4997                          Asia      Myanmar   Baby Food       Offline
# 4998                        Europe      Finland     Clothes        Online
# 4999            Sub-Saharan Africa     Tanzania  Vegetables        Online
#
#      Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 4995              C    4/3/2015  217984473   4/20/2015        5305
# 4996              L   8/17/2014  169748055   10/2/2014        1077
# 4997              H  11/23/2016  226939189  12/10/2016        5204
# 4998              L   4/22/2014  906794202   5/11/2014        9410
# 4999              L    7/8/2011  996861922    8/7/2011        2450
#
#       Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df.describe()
# Out:
#            Order ID   Units Sold   Unit Price    Unit Cost  Total Revenue  \
# count  5.000000e+03  5000.000000  5000.000000  5000.000000   5.000000e+03
# mean   5.486447e+08  5030.698200   265.745564   187.494144   1.325738e+06
# std    2.594671e+08  2914.515427   218.716695   176.416280   1.475375e+06
# min    1.000909e+08     2.000000     9.330000     6.920000   6.531000e+01
# 25%    3.201042e+08  2453.000000    81.730000    35.840000   2.574168e+05
# 50%    5.523150e+08  5123.000000   154.060000    97.440000   7.794095e+05
# 75%    7.687709e+08  7576.250000   437.200000   263.330000   1.839975e+06
# max    9.998797e+08  9999.000000   668.270000   524.960000   6.672676e+06
#
#          Total Cost  Total Profit
# count  5.000000e+03  5.000000e+03
# mean   9.330932e+05  3.926446e+05
# std    1.150873e+06  3.829351e+05
# min    4.844000e+01  1.687000e+01
# 25%    1.547480e+05  8.533925e+04
# 50%    4.681807e+05  2.790952e+05
# 75%    1.189578e+06  5.651064e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          5000 non-null   object
#  1   Country         5000 non-null   object
#  2   Item Type       5000 non-null   object
#  3   Sales Channel   5000 non-null   object
#  4   Order Priority  5000 non-null   object
#  5   Order Date      5000 non-null   object
#  6   Order ID        5000 non-null   int64
#  7   Ship Date       5000 non-null   object
#  8   Units Sold      5000 non-null   int64
#  9   Unit Price      5000 non-null   float64
#  10  Unit Cost       5000 non-null   float64
#  11  Total Revenue   5000 non-null   float64
#  12  Total Cost      5000 non-null   float64
#  13  Total Profit    5000 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 547.0+ KB

# %%
df.sample()
# Out:
#       Region Country   Item Type Sales Channel Order Priority Order Date  \
# 1349  Europe  Kosovo  Vegetables       Offline              C  7/23/2017
#
#        Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# 1349  975080668  8/20/2017        6893      154.06      90.93     1061935.58
#
#       Total Cost  Total Profit
# 1349   626780.49     435155.09

# %%
df.nunique()
# Out:
# Region               7
# Country            185
# Item Type           12
# Sales Channel        2
# Order Priority       4
# Order Date        2305
# Order ID          5000
# Ship Date         2320
# Units Sold        3944
# Unit Price          12
# Unit Cost           12
# Total Revenue     4909
# Total Cost        4908
# Total Profit      4909
# dtype: int64

# %%
df.nsmallest(5, 'Units Sold')
# Out:
#                                  Region                 Country  \
# 582                                Asia                  Brunei
# 1046                             Europe                Bulgaria
# 1405                 Sub-Saharan Africa                  Rwanda
# 2244                             Europe  Bosnia and Herzegovina
# 3284  Central America and the Caribbean  Saint Kitts and Nevis
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 582         Baby Food        Online              C   4/19/2012  918961560
# 1046        Household        Online              C   3/21/2014  129902875
# 1405          Clothes        Online              M  10/23/2013  410077846
# 2244  Office Supplies       Offline              C    5/2/2010  152746713
# 3284          Clothes       Offline              L  10/14/2013  532441079
#
#       Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# ...

# %%
df.nlargest(5, 'Unit Cost')
# Out:
#                                Region    Country        Item Type  \
# 10       Middle East and North Africa     Turkey  Office Supplies
# 17                             Europe   Bulgaria  Office Supplies
# 27  Central America and the Caribbean  Guatemala  Office Supplies
# 45                 Sub-Saharan Africa     Angola  Office Supplies
# 51                               Asia       Laos  Office Supplies
#
#    Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 10       Offline              C   9/25/2013  557156026  10/15/2013
# 17        Online              L  10/31/2010  672330081  11/29/2010
# 27        Online              M   1/17/2012  345820701    2/1/2012
# 45       Offline              C   10/3/2015  778854548   10/3/2015
# 51        Online              H   8/10/2012  197185981   9/11/2012
#
#     Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 10        3704      651.21     524.96     2412081.84  1944451.84     467630.00
# ...

# %%
for idx, row in df.iterrows():
    print(row)
    print('---------')
    print(row['Region'])
    break
# Out:
# Region            Central America and the Caribbean
# Country                        Antigua and Barbuda
# Item Type                                 Baby Food
# Sales Channel                                Online
# Order Priority                                    M
# Order Date                               12/20/2013
# Order ID                                  957081544
# Ship Date                                 1/11/2014
# Units Sold                                      552
# Unit Price                                   255.28
# Unit Cost                                    159.42
# Total Revenue                             140914.56
# Total Cost                                 87999.84
# Total Profit                               52914.72
# Name: 0, dtype: object
# ---------
# Central America and the Caribbean

# %%
# df.to_dict()

# %%
new_df = df.copy()
new_df.head()
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales Channel Order Priority  Order Date   Order ID  Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544  1/11/2014         552
# 1       Offline              C    7/5/2010  301644504  7/26/2010        2167
# 2       Offline              C   9/12/2011  478051030  9/29/2011        4778
# 3       Offline              L   5/13/2010  892599952  6/15/2010        9016
# 4       Offline              C   7/20/2015  571902596  7/27/2015        7542
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df.isna().any()
# Out:
# Region            False
# Country           False
# Item Type         False
# Sales Channel     False
# Order Priority    False
# Order Date        False
# Order ID          False
# Ship Date         False
# Units Sold        False
# Unit Price        False
# Unit Cost         False
# Total Revenue     False
# Total Cost        False
# Total Profit      False
# dtype: bool

# %%
df.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df[1000:]
# Out:
#                                  Region                 Country  \
# 1000                             Europe  Bosnia and Herzegovina
# 1001                             Europe                 Belarus
# 1002                             Europe                Slovenia
# 1003              Australia and Oceania                Kiribati
# 1004  Central America and the Caribbean              Costa Rica
# ...                                 ...                     ...
# 4995              Australia and Oceania             New Zealand
# 4996       Middle East and North Africa              Azerbaijan
# 4997                               Asia                 Myanmar
# 4998                             Europe                 Finland
# 4999                 Sub-Saharan Africa                Tanzania
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 1000           Cereal        Online              C   3/30/2011  639126908
# ...

# %%
df[1000:1200]
# Out:
#                                  Region                 Country  \
# 1000                             Europe  Bosnia and Herzegovina
# 1001                             Europe                 Belarus
# 1002                             Europe                Slovenia
# 1003              Australia and Oceania                Kiribati
# 1004  Central America and the Caribbean              Costa Rica
# ...                                 ...                     ...
# 1195                             Europe           Liechtenstein
# 1196              Australia and Oceania        Marshall Islands
# 1197       Middle East and North Africa                Pakistan
# 1198                             Europe                  Norway
# 1199       Middle East and North Africa            Saudi Arabia
#
#             Item Type Sales Channel Order Priority Order Date   Order ID  \
# 1000           Cereal        Online              C  3/30/2011  639126908
# ...

# %%
df.iloc[1000, 3]
# Out:
# 'Online'

# %%
df.iloc[1000]
# Out:
# Region                            Europe
# Country           Bosnia and Herzegovina
# Item Type                         Cereal
# Sales Channel                     Online
# Order Priority                         C
# Order Date                     3/30/2011
# Order ID                       639126908
# Ship Date                      5/10/2011
# Units Sold                           710
# Unit Price                         205.7
# Unit Cost                         117.11
# Total Revenue                   146047.0
# Total Cost                       83148.1
# Total Profit                     62898.9
# Name: 1000, dtype: object

# %%
df.loc[1000, 'Sales Channel']
# Out:
# 'Online'

# %%
df['Item Type']
# Out:
# 0        Baby Food
# 1           Snacks
# 2        Beverages
# 3           Cereal
# 4           Snacks
#            ...
# 4995     Household
# 4996       Clothes
# 4997     Baby Food
# 4998       Clothes
# 4999    Vegetables
# Name: Item Type, Length: 5000, dtype: object

# %%
new_df = df[df['Unit Cost'] > 100]
new_df
# Out:
#                                  Region               Country  \
# 0     Central America and the Caribbean  Antigua and Barbuda
# 3                                  Asia           North Korea
# 9                    Sub-Saharan Africa              Ethiopia
# 10         Middle East and North Africa                Turkey
# 11         Middle East and North Africa                  Oman
# ...                                 ...                   ...
# 4990                             Europe               Ukraine
# 4991                             Europe               Armenia
# 4994                 Sub-Saharan Africa               Liberia
# 4995              Australia and Oceania           New Zealand
# 4997                               Asia               Myanmar
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 0           Baby Food        Online              M  12/20/2013  957081544
# ...

# %%
new_df = df[(df['Unit Cost'] > 100) & (df['Region'] == 'Asia')]
new_df
# Out:
#      Region      Country        Item Type Sales Channel Order Priority  \
# 3      Asia  North Korea           Cereal       Offline              L
# 12     Asia     Malaysia           Cereal       Offline              L
# 42     Asia         Laos             Meat        Online              L
# 49     Asia       Taiwan        Baby Food        Online              M
# 51     Asia         Laos  Office Supplies        Online              H
# ...     ...          ...              ...           ...            ...
# 4970   Asia      Myanmar        Baby Food        Online              M
# 4974   Asia     Malaysia  Office Supplies       Offline              L
# 4985   Asia         Laos        Cosmetics       Offline              L
# 4986   Asia    Sri Lanka  Office Supplies        Online              C
# 4997   Asia      Myanmar        Baby Food       Offline              H
#
#       Order Date   Order ID   Ship Date  Units Sold  Unit Price  Unit Cost  \
# ...

# %%
df[df['Country'].isin(['Turkey', 'Lebanon', 'Taiwan'])]
# Out:
#                             Region  Country        Item Type Sales Channel  \
# 10    Middle East and North Africa   Turkey  Office Supplies       Offline
# 15    Middle East and North Africa  Lebanon             Meat       Offline
# 34    Middle East and North Africa  Lebanon           Fruits        Online
# 47    Middle East and North Africa  Lebanon        Household       Offline
# 49                            Asia   Taiwan        Baby Food        Online
# ...                            ...      ...              ...           ...
# 4508                          Asia   Taiwan           Cereal       Offline
# 4513                          Asia   Taiwan             Meat        Online
# 4725  Middle East and North Africa   Turkey    Personal Care        Online
# 4740                          Asia   Taiwan           Fruits        Online
# 4778  Middle East and North Africa   Turkey             Meat       Offline
#
# ...

# %%
df[df['Country'].str.startswith('T')]
# Out:
#                                  Region              Country        Item Type  \
# 10         Middle East and North Africa               Turkey  Office Supplies
# 19    Central America and the Caribbean  Trinidad and Tobago        Baby Food
# 23                Australia and Oceania               Tuvalu        Beverages
# 49                                 Asia               Taiwan        Baby Food
# 53                Australia and Oceania               Tuvalu        Household
# ...                                 ...                  ...              ...
# 4912                 Sub-Saharan Africa           The Gambia       Vegetables
# 4956                 Sub-Saharan Africa             Tanzania           Snacks
# 4961              Australia and Oceania               Tuvalu    Personal Care
# 4989                               Asia             Thailand           Snacks
# 4999                 Sub-Saharan Africa             Tanzania       Vegetables
#
# ...

# %%
df[~df['Country'].str.contains('a')]
# Out:
#                                  Region                Country  \
# 2                                Europe         Czech Republic
# 5          Middle East and North Africa                Morocco
# 10         Middle East and North Africa                 Turkey
# 18                        North America                 Mexico
# 26                               Europe             Montenegro
# ...                                 ...                    ...
# 4950                 Sub-Saharan Africa                  Benin
# 4957  Central America and the Caribbean                 Belize
# 4960                 Sub-Saharan Africa                  Niger
# 4965                 Sub-Saharan Africa  Republic of the Congo
# 4967                 Sub-Saharan Africa                Lesotho
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 2           Beverages       Offline              C   9/12/2011  478051030
# ...

# %%
# new_df['Grade'] = [50,60,...........]
# new_df

# %%
new_df.drop('Item Type', axis=1, inplace=True)
new_df
# Out:
# <ipython-input-102-7495b3c4c244>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop('Item Type', axis=1, inplace=True)
#      Region      Country Sales Channel Order Priority  Order Date   Order ID  \
# 3      Asia  North Korea       Offline              L   5/13/2010  892599952
# 12     Asia     Malaysia       Offline              L   7/31/2016  333942162
# 42     Asia         Laos        Online              L   3/21/2017  734708821
# 49     Asia       Taiwan        Online              M   5/27/2014  369560611
# 51     Asia         Laos        Online              H   8/10/2012  197185981
# ...     ...          ...           ...            ...         ...        ...
# 4970   Asia      Myanmar        Online              M    6/6/2012  670026814
# ...

# %%
df.drop(index=[0, 1])
df
# Out:
#                                  Region               Country   Item Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
# Out:
#      Region      Country Sales Channel Order Priority  Order Date   Order ID  \
# 3      Asia  North Korea       Offline              L   5/13/2010  892599952
# 12     Asia     Malaysia       Offline              L   7/31/2016  333942162
# 42     Asia         Laos        Online              L   3/21/2017  734708821
# 49     Asia       Taiwan        Online              M   5/27/2014  369560611
# 51     Asia         Laos        Online              H   8/10/2012  197185981
# ...     ...          ...           ...            ...         ...        ...
# 4970   Asia      Myanmar        Online              M    6/6/2012  670026814
# 4974   Asia     Malaysia       Offline              L  11/25/2011  699801480
# 4985   Asia         Laos       Offline              L  10/13/2010  580309283
# 4986   Asia    Sri Lanka        Online              C   12/1/2012  307045400
# 4997   Asia      Myanmar       Offline              H  11/23/2016  226939189
#
# ...

# %%
df.sort_values(by='Units Sold', ascending=False)
# Out:
#                                  Region                 Country  \
# 1508                             Europe          United Kingdom
# 3923                             Europe                Portugal
# 1985                             Europe                 Ireland
# 2564  Central America and the Caribbean                Dominica
# 3378                               Asia                Thailand
# ...                                 ...                     ...
# 2244                             Europe  Bosnia and Herzegovina
# 1046                             Europe                Bulgaria
# 3284  Central America and the Caribbean  Saint Kitts and Nevis
# 1405                 Sub-Saharan Africa                  Rwanda
# 582                                Asia                  Brunei
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 1508    Personal Care       Offline              H  12/23/2013  387098824
# ...

# %%
df_group = df.groupby('Region')
df_group

# %%
df.dropna()
# Out:
#                                  Region               Country   Item Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
df.dropna(subset=['Unit Price'])
# Out:
#                                  Region               Country   Item Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
df.fillna(10)
# Out:
#                                  Region               Country   Item Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
df.drop_duplicates()
# Out:
#                                  Region               Country   Item Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
df['Unit Price'].sum()
# Out:
# 1328727.8199999998

# %%
df['Unit Price'].max()
# Out:
# 668.27

# %%
df['Unit Price'].min()
# Out:
# 9.33

# %%
df['Unit Price'].mean()
# Out:
# 265.74556399999994

# %%
df['Unit Price'].median()
# Out:
# 154.06

# %%
df['Unit Price'].idxmax()
# Out:
# 47

# %%
df.iloc[47]
# Out:
# Region            Middle East and North Africa
# Country                                Lebanon
# Item Type                            Household
# Sales Channel                          Offline
# Order Priority                               M
# Order Date                          10/15/2014
# Order ID                             198997008
# Ship Date                           10/16/2014
# Units Sold                                6492
# Unit Price                              668.27
# Unit Cost                               502.54
# Total Revenue                       4338408.84
# Total Cost                          3262489.68
# Total Profit                        1075919.16
# Name: 47, dtype: object

# %%
df['Unit Price'].idxmin()
# Out:
# 22

# %%
df.iloc[22]
# Out:
# Region               Europe
# Country             Estonia
# Item Type            Fruits
# Sales Channel        Online
# Order Priority            L
# Order Date        9/28/2016
# Order ID          579463422
# Ship Date         11/1/2016
# Units Sold             4958
# Unit Price             9.33
# Unit Cost              6.92
# Total Revenue      46258.14
# Total Cost         34309.36
# Total Profit       11948.78
# Name: 22, dtype: object
